# %% [markdown]
# ## Function to insert data in LogData table

# %%
def insert_into_logdata(run_id, sequence_no, LogDate, LogType, ObjectName, ActivityName, Description):
    log_table = 'abfss://0b8848ac-eb9d-4f63-89f0-7b35fd567869@onelake.dfs.fabric.microsoft.com/95a8ae81-fd35-4c23-a7e6-362267605f81/Tables/logdata'

    log_data = spark.createDataFrame([(run_id, sequence_no, LogDate, LogType, ObjectName, ActivityName, Description)],\
                                    ["RunID", "SequenceNo", "LogDate", "LogType", "ObjectName", "ActivityName", "Description"])

    log_data.write.mode("append").save(log_table)

# %% [markdown]
# #### Defined generic variables

# %%
lh_raw_table_path = "abfss://0b8848ac-eb9d-4f63-89f0-7b35fd567869@onelake.dfs.fabric.microsoft.com/df219fea-4267-4b36-8d41-4362845d2cd5/Tables/"
lh_curated_table_path = "abfss://0b8848ac-eb9d-4f63-89f0-7b35fd567869@onelake.dfs.fabric.microsoft.com/a83dfd23-28d5-4d7f-9398-54f3814e7225/Tables/"
lh_refined_path = "abfss://0b8848ac-eb9d-4f63-89f0-7b35fd567869@onelake.dfs.fabric.microsoft.com/95a8ae81-fd35-4c23-a7e6-362267605f81/Tables/"

lh_raw_d365_table_path = "abfss://0b8848ac-eb9d-4f63-89f0-7b35fd567869@onelake.dfs.fabric.microsoft.com/43669a52-b49f-421a-817d-83aede437777/Tables/"
lh_curated_d365_table_path = "abfss://0b8848ac-eb9d-4f63-89f0-7b35fd567869@onelake.dfs.fabric.microsoft.com/ce9e9494-f5dc-4eee-a70c-5523fa2c37f5/Tables/"
lh_refined_d365_table_path = "abfss://0b8848ac-eb9d-4f63-89f0-7b35fd567869@onelake.dfs.fabric.microsoft.com/7fe67431-0aef-4acb-a5b0-f83480226854/Tables/"

lh_sandbox_table_path = "abfss://c3d259cf-f20c-4a8e-9d62-64723e7c1182@onelake.dfs.fabric.microsoft.com/ea2af2d4-4f5c-4b47-a5d3-396deb900ebf/Tables/"



activityLog_table_path = "abfss://0b8848ac-eb9d-4f63-89f0-7b35fd567869@onelake.dfs.fabric.microsoft.com/6ce9e402-1e20-497a-812d-dbe1948e7999/Tables/activity_log"

# %% [markdown]
# ## Function to insert data in ActivityLog table

# %%
# def insert_into_activitylog(source_lakehouse, source_type, source_name, destination_lakehouse,destination_type,destination_name, start_time, end_time, activity, source_count, destination_count, baddata_count):
#     activity_log_table = 'abfss://CJDarcl@onelake.dfs.fabric.microsoft.com/LH_Refined.Lakehouse/Tables/activity_log'
#     log_data = spark.createDataFrame([(source_lakehouse, source_type, source_name, destination_lakehouse,destination_type,destination_name, start_time, end_time, activity, source_count, destination_count, baddata_count)], \
#                                     ["Source_Location","Source_Type","Source_Name", "Destination_Location","Destination_Type","Destination_Name", "Start_Time","End_Time", "Activity", "Source_Count", "Destination_Count", "BadData_Count"])


#     log_data.write.mode("append").save(activity_log_table)
